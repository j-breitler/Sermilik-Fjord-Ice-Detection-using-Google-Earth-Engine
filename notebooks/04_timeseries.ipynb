# %% [markdown]
# # WP4: Ice Area Time Series & Anomaly Detection
#
# Extract per-image ice-covered area (km²), build a time series, and flag anomalies.

# %%
import ee
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '..')
from src.utils import load_aoi, get_gee_project
from src.timeseries import collection_to_timeseries, detect_anomalies

ee.Initialize(project=get_gee_project())
aoi = load_aoi()

# %% [markdown]
# ## 4.1 Build time series from fused classification
#
# > Run 03_classification.ipynb first and pass the fused collection here.

# %%
# fused_collection = ...  # from WP3
# df = collection_to_timeseries(fused_collection, aoi, band='ice_fused')
# df.to_csv('../outputs/csv/ice_area_timeseries.csv', index=False)
# df.head()

# %% [markdown]
# ## 4.2 Load saved time series and detect anomalies

# %%
import pandas as pd

# df = pd.read_csv('../outputs/csv/ice_area_timeseries.csv', parse_dates=['date'])
# df = detect_anomalies(df)
# df.head()

# %% [markdown]
# ## 4.3 Plot time series

# %%
# fig, ax = plt.subplots(figsize=(14, 4))
# ax.plot(df['date'], df['ice_area_km2'], lw=0.8, label='Ice area')
# ax.plot(df['date'], df['rolling_mean'], lw=1.5, label='30-day mean')
# ax.scatter(df.loc[df['anomaly'], 'date'], df.loc[df['anomaly'], 'ice_area_km2'],
#            color='red', s=20, label='Anomaly')
# ax.set(xlabel='Date', ylabel='Ice area (km²)', title='Sermilik Fjord sea ice 2019–2024')
# ax.legend()
# fig.savefig('../outputs/figures/ice_area_timeseries.png', dpi=150, bbox_inches='tight')
# plt.show()
