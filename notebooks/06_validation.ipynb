# %% [markdown]
# # WP6: Validation & Accuracy Assessment
#
# Compute confusion matrix, overall accuracy, and kappa coefficient against reference data (NICFI Planet basemaps or DMI ice charts).

# %%
import ee
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score
import sys
sys.path.insert(0, '..')
from src.utils import load_aoi, get_gee_project

ee.Initialize(project=get_gee_project())
aoi = load_aoi()

# %% [markdown]
# ## 6.1 Sample validation points
#
# Create or load a validation FeatureCollection with `true_class` and `pred_class` properties.

# %%
# TODO: load your GEE validation asset
# val_fc = ee.FeatureCollection('users/your-username/sermilik_validation')
# val_df = pd.DataFrame([f['properties'] for f in val_fc.getInfo()['features']])
# y_true = val_df['true_class']
# y_pred = val_df['pred_class']

# %% [markdown]
# ## 6.2 Confusion matrix

# %%
# classes = ['open water', 'sea ice', 'ice melange', 'land']
# cm = confusion_matrix(y_true, y_pred)
# fig, ax = plt.subplots(figsize=(6, 5))
# sns.heatmap(cm, annot=True, fmt='d', xticklabels=classes, yticklabels=classes, cmap='Blues', ax=ax)
# ax.set(xlabel='Predicted', ylabel='True', title='Confusion matrix')
# fig.savefig('../outputs/figures/confusion_matrix.png', dpi=150, bbox_inches='tight')
# plt.show()
# print(classification_report(y_true, y_pred, target_names=classes))
# print(f'Kappa: {cohen_kappa_score(y_true, y_pred):.3f}')
